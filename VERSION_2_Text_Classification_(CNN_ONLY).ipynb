# %% [markdown]
# <a href="https://colab.research.google.com/github/tz2004a/sklearnWork/blob/Google-Colab-Notebooks/VERSION_2_Text_Classification_(CNN_ONLY).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install scikit-learn

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import models, layers, callbacks
from gensim.models import KeyedVectors
from urllib.request import urlopen

# %%
# Install necessary modules
# %pip install gensim
# %pip install nltk

# %%
### Prepping the data as a whole
# Doing the first steps
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec
from google.colab import drive

drive.mount('/content/drive')

# Now for the actual data
import pandas as pd
path = "/content/drive/MyDrive/word2vec/20newsgroups_data.csv"
df = pd.read_csv(path)

# Getting the texts and labels
texts = df.iloc[:,1:]
labels = df.iloc[:,0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Preparing the testing and training data
X_train_wordvec, X_test_wordvec, y_train_wordvec, y_test_wordvec = train_test_split(texts, labels, test_size=0.2, random_state=42)

# %%
# Create a Word2Vec Representation
from gensim.models import Word2Vec

sentences = [doc.split() for doc in texts]

# I think we need to do something similar to what we did before
# Loop through every single row in the texts dataframe
#FIXED_X_train_wordvec_arr = []
#X_train_wordvec_arr = X_train_wordvec.to_numpy()
#for x in X_train_wordvec_arr:
#  FIXED_X_train_wordvec_arr.append()

model = Word2Vec(sentences, min_count=1)

# %%
model

# %%
X_train_wordvec
# Out:
#                workclass  fnlwgt      education  education-num  \
# 37193            Private  145175   Some-college             10
# 31093   Self-emp-not-inc  175029           10th              6
# 33814          Local-gov  172664        HS-grad              9
# 14500            Private  125791        HS-grad              9
# 23399            Private   28419      Assoc-voc             11
# ...                  ...     ...            ...            ...
# 11284            Private  635913        HS-grad              9
# 44732            Private  107624   Some-college             10
# 38158            Private  250135   Some-college             10
# 860            State-gov   96652      Assoc-voc             11
# 15795            Private  176118        Masters             14
#
#                marital-status          occupation    relationship    race  \
# 37193      Married-civ-spouse   Machine-op-inspct         Husband   White
# ...

# %%
texts_arr = texts.to_numpy()

# %%
texts_arr[0]
# Out:
# array([' Private', 226802, ' 11th', 7, ' Never-married',
#        ' Machine-op-inspct', ' Own-child', ' Black', ' Male', 0, 0, 40,
#        ' United-States', ' <=50K'], dtype=object)

# %%
# Doing the first steps
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec
from google.colab import drive

drive.mount('/content/drive')
#word2vec_model = KeyedVectors.load_word2vec_format('path/to/word2vec_model.bin', binary=True)  # Replace with actual path
#X_word2vec = np.array([np.mean([word2vec_model[word] for word in text.split() if word in word2vec_model], axis=0) for text in texts])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Use a pre-trained Word2Vec embedding to encode data
import pandas as pd
path = "/content/drive/MyDrive/word2vec/20newsgroups_data.csv"
df = pd.read_csv(path)

# Dataset is now stored in a Pandas DataFrame
df.describe
# Out:
# <bound method NDFrame.describe of        age      workclass  fnlwgt      education  education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 4       18              ?  103497   Some-college             10
# ...    ...            ...     ...            ...            ...
# 48837   27        Private  257302     Assoc-acdm             12
# 48838   40        Private  154374        HS-grad              9
# 48839   58        Private  151910        HS-grad              9
# 48840   22        Private  201490        HS-grad              9
# 48841   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 0            Never-married   Machine-op-inspct    Own-child   Black     Male
# ...

# %%
# Create a Word2Vec Representation
from gensim.models import Word2Vec

sentences = [doc.split() for doc in df.iloc[:,1:]]
model = Word2Vec(sentences, min_count=1)

# %%
# Train and Testing Data Split

# %%
type(df.iloc[:,1])
# Out:
# pandas.core.series.Series

# %%
df.iloc[:,1:]
# Out:
#            workclass  fnlwgt      education  education-num  \
# 0            Private  226802           11th              7
# 1            Private   89814        HS-grad              9
# 2          Local-gov  336951     Assoc-acdm             12
# 3            Private  160323   Some-college             10
# 4                  ?  103497   Some-college             10
# ...              ...     ...            ...            ...
# 48837        Private  257302     Assoc-acdm             12
# 48838        Private  154374        HS-grad              9
# 48839        Private  151910        HS-grad              9
# 48840        Private  201490        HS-grad              9
# 48841   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 0            Never-married   Machine-op-inspct    Own-child   Black     Male
# 1       Married-civ-spouse     Farming-fishing      Husband   White     Male
# ...

# %%
df
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 4       18              ?  103497   Some-college             10
# ...    ...            ...     ...            ...            ...
# 48837   27        Private  257302     Assoc-acdm             12
# 48838   40        Private  154374        HS-grad              9
# 48839   58        Private  151910        HS-grad              9
# 48840   22        Private  201490        HS-grad              9
# 48841   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 0            Never-married   Machine-op-inspct    Own-child   Black     Male
# ...

# %%
sentences
# Out:
# [['Private'],
#  ['Private'],
#  ['Local-gov'],
#  ['Private'],
#  ['?'],
#  ['Private'],
#  ['?'],
#  ['Self-emp-not-inc'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Federal-gov'],
#  ['Private'],
#  ['?'],
#  ['Private'],
#  ['Private'],
#  ['State-gov'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['?'],
#  ['Private'],
#  ['Private'],
#  ['Self-emp-not-inc'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Self-emp-not-inc'],
#  ['State-gov'],
#  ['Self-emp-not-inc'],
#  ['Self-emp-not-inc'],
#  ['Local-gov'],
#  ['Private'],
#  ['?'],
#  ['Local-gov'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Self-emp-inc'],
#  ['Private'],
#  ['Private'],
#  ['State-gov'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Self-emp-inc'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Private'],
#  ['Local-gov'],
#  ['Self-emp-inc'],
# ...

# %%
model
